# %% [markdown]
# ### Derin Gezgin

# %% [markdown]
# ## COM110 Lab8: Language Analysis
# ### dict, set, tuple, list, str
# <img src="https://resilienteducator.com/wp-content/uploads/2015/09/Revising-With-Pictures-How-Word-Clouds-Help-Students-Become-Better-Writers.jpg" width="700">
# (c) 2023 Timothy Becker, Department of Computer Science <br><br>
# <img src="https://www.conncoll.edu/media/website-media/visualidentity/images/1Line-LogoSig-Color.jpg" width="200">

# %% [markdown]
# ### Preface
# We can analysis texts in a computational manner thus providing a different set of insights than those which we gather by reading and applying critical thought to the texts. Here we will use several plays in text form as the input for our analysis and we will look into these texts and ask questions about the words being used: which ones are used most and least frequently, which ones appear together often? Using this analysis framework you can dig even deeper into the word choices of authors along with higher level features such as tone. To get started we will first make use of some text processing in order to chop the text portion of the text into str data types. This lab will then make use of the CH11 data structures to provide some interesting and novel analysis that a human reader would have difficulty performing (without the use of a computer).

# %% [markdown]
# ### [Part 1 20 pts] Processing text and counting occurrences
# First, we will read in and process the plays. the read_and_process function below will perform some heavy lifting for you to chop off the ACTs, Scenes, the speaker name, the empty lines, the punctuations and other artifacts. This will provide the text in word form with spaces separating. You will then proceed by using string processing tools and will make use of data structures. The following text processing code illustrates how easy it is (or just powerful) to process raw text in python. There really is now need in a language like this to have to use libraries to read txt, csv, tsv or any other structure text form (.xls is another story)

# %%
import re #pattern matching library look at re.sub(r'\([^)]*\)','',line) it removes ()

def read_and_process_text(path):
    raw = []
    with open(path,'r') as f:
        raw = [line.replace('\n','') for line in f.readlines()]
        if '\n'.join(raw).find(' ACT ')>=0:
            i = 0                                    
            for i in range(len(raw)):              
                if raw[i].startswith('ACT '): break  
            raw = raw[i:]

    data = []
    for line in raw:
        if not (line.startswith('ACT') or line.startswith('=') or line.startswith('Scene')):
            chunk = re.sub(r'\[[^)]*\]','',re.sub(r'\([^)]*\)','',line)).replace('--','').replace('\'','').replace('\t','')
            if chunk!='': 
                data += [chunk.replace('(','').replace(')','').replace('[','').replace(']','').replace(';','').replace(':','')]

    filt = []
    for line in data:
        first = line.split(' ')[0]
        if len(first)>1 and first==first.upper():  #more than a single char in uppercase=> I it is a speaker
            chunk = line.replace(first,'').strip() #replace the speaker name with empty string then clear away the leading space!
            if chunk!='': filt += [chunk]
        else: filt += [line]
    text = ' '.join(re.split('[.!?]',' '.join(filt).replace(',','').replace('"','').replace(':','')))
    text = re.sub(' +',' ',text)             #clear away runs of spaces
    text = re.sub(r'[^\x00-\x7F]','', text) #remove wierd unicode characters
    return text

lear = read_and_process_text('king_lear_shakespeare.txt')
lear[:1000]
# Out:
# 'King Lear by William Shakespeare Edited by Barbara A Mowat and Paul Werstine with Michael Poston and Rebecca Niles Folger Shakespeare Library https//shakespeare folger edu/shakespeares-works/king-lear/ Created on Jul 31 2015 from FDT version 0 9 2 Characters in the Play king of Britain Lears eldest daughter OF ALBANY her husband her steward Lears second daughter OF CORNWALL her husband Lears youngest daughter OF FRANCE her suitor and then husband OF BURGUNDY her suitor OF KENT OF GLOUCESTER his elder son his younger and illegitimate son gentleman of Gloucesters household MAN a tenant of Gloucesters serving Lear Three SERVANTS Knights in Lears train Servants Officers Soldiers Attendants Gentlemen I thought the King had more affected the Duke of Albany than Cornwall It did always seem so to us but now in the division of the kingdom it appears not which of the dukes he values most for equalities are so weighed that curiosity in neither can make choice of eithers moiety Is not this your so'

# %% [markdown]
# #### [Exercise 1a]
# Get all the unique words in the King Lear play. How many words are used here?  Does number of words indicate anything in a play? You can use sets here and are not permitted any libraries. Splitting the result of the read_and_process_text will give you text that can be split on the space.

# %%
#Exercise 1a code here

# Splitting the lear text by spaces
# Converting it to a set
# Finding its length
# Out:
# 4723

# %% [markdown]
# #### [Exercise 1b]
# Now get the frequency of each word in the King Lear play using loops and dictionaries. You are not permitted to use any libraries here. This idea was shown in class for counting letters in a string. Here you should break the string into words and then use the whole word as a dict key.

# %%
#[Example 1] how to count individual letter in a string s

s = "Any text can be put here. Each character will be counted up by this algorithm!"

D = {}            #start with an empty dictionary, they have K:V pairs, usually a str, int or tuple
for x in s:       #loop on each char of the string s
    if x in D:    #check for membership in D (this is very fast O(1) operations unlike a list which takes O(n))
        D[x] += 1 #since the key is in D, use the key to access the value in D => D[x] is the value of key x in dictionary D
    else:
        D[x] = 1  #there is no key so this will add the key x, value 1 to the dictionary D
        
print(D)          #print dict
# Out:
# {'A': 1, 'n': 3, 'y': 2, ' ': 14, 't': 7, 'e': 7, 'x': 1, 'c': 5, 'a': 5, 'b': 3, 'p': 2, 'u': 3, 'h': 5, 'r': 4, '.': 1, 'E': 1, 'w': 1, 'i': 3, 'l': 3, 'o': 2, 'd': 1, 's': 1, 'g': 1, 'm': 1, '!': 1}

# %%
# we can also reorder our results using the frequencies we calculated above
E = {} #make a new dict
sorted_keys = sorted(D,key=lambda x: D[x]) #sorted the dictionary keys by the value: aka the frequicies/ints
sorted_keys = sorted_keys[::-1]            #sorted is ascending so we reverse the list
for k in sorted_keys:                      #loop through the keys
    E[k] = D[k]                            #and no reorder the keys in D into our new dict E
D = E                                      #swap the object references from E to D
print(D)

D = {k:D[k] for k in sorted(D,key=lambda x: D[x])[::-1]} #or do all the steps above in one line...
print(D)
# Out:
# {' ': 14, 'e': 7, 't': 7, 'h': 5, 'a': 5, 'c': 5, 'r': 4, 'l': 3, 'i': 3, 'u': 3, 'b': 3, 'n': 3, 'o': 2, 'p': 2, 'y': 2, '!': 1, 'm': 1, 'g': 1, 's': 1, 'd': 1, 'w': 1, 'E': 1, '.': 1, 'x': 1, 'A': 1}
# {' ': 14, 't': 7, 'e': 7, 'c': 5, 'a': 5, 'h': 5, 'r': 4, 'n': 3, 'b': 3, 'u': 3, 'i': 3, 'l': 3, 'y': 2, 'p': 2, 'o': 2, 'A': 1, 'x': 1, '.': 1, 'E': 1, 'w': 1, 'd': 1, 's': 1, 'g': 1, 'm': 1, '!': 1}

# %%
#Exercise 1b code here

s = lear.split(" ") # Splitting the lear text by words. 

D = {}            # Creating an empty dictionary
for x in s:       # Looping every word in s
    if x in D:    # Checking if the word is already in the dictionary
        D[x] += 1 # If it is, increasing it 1
    else:
        D[x] = 1  # If it's not in the dictionary, creating a key and setting it's value to 1
        
print(D)          # Printing the dictionary

### Sorting the Dictionary ### (Not required but wanted to do) ###
D = {k:D[k] for k in sorted(D,key=lambda x: D[x])[::-1]} # Sorting the words
print(D)    # Printing the sorted form
# Out:
# {'King': 42, 'Lear': 22, 'by': 67, 'William': 1, 'Shakespeare': 2, 'Edited': 1, 'Barbara': 1, 'A': 48, 'Mowat': 1, 'and': 542, 'Paul': 1, 'Werstine': 1, 'with': 168, 'Michael': 1, 'Poston': 1, 'Rebecca': 1, 'Niles': 1, 'Folger': 1, 'Library': 1, 'https//shakespeare': 1, 'folger': 1, 'edu/shakespeares-works/king-lear/': 1, 'Created': 1, 'on': 98, 'Jul': 1, '31': 1, '2015': 1, 'from': 81, 'FDT': 1, 'version': 1, '0': 1, '9': 1, '2': 1, 'Characters': 1, 'in': 267, 'the': 661, 'Play': 1, 'king': 27, 'of': 446, 'Britain': 1, 'Lears': 6, 'eldest': 3, 'daughter': 32, 'OF': 6, 'ALBANY': 1, 'her': 128, 'husband': 12, 'steward': 1, 'second': 2, 'CORNWALL': 1, 'youngest': 4, 'FRANCE': 1, 'suitor': 2, 'then': 30, 'BURGUNDY': 1, 'KENT': 1, 'GLOUCESTER': 1, 'his': 182, 'elder': 2, 'son': 29, 'younger': 3, 'illegitimate': 1, 'gentleman': 11, 'Gloucesters': 7, 'household': 1, 'MAN': 10, 'a': 325, 'tenant': 3, 'serving': 1, 'Three': 1, 'SERVANTS': 1, 'Knights': 1, 'train': 8, 'Servants': 4, 'Officers': 1, 'Soldiers': 6, 'Attendants': 3, 'Gentlemen': 3, 'I': 614, 'thought': 13, 'had': 35, 'more': 76, 'affected': 2, 'Duke': 18, 'Albany': 8, 'than': 51, 'Cornwall': 15, 'It': 25, 'did': 18, 'always': 2, 'seem': 6, 'so': 101, 'to': 410, 'us': 52, 'but': 71, 'now': 48, 'division': 3, 'kingdom': 12, 'it': 163, 'appears': 4, 'not': 261, 'which': 46, 'dukes': 5, 'he': 119, 'values': 1, 'most': 42, 'for': 114, 'equalities': 1, 'are': 114, 'weighed': 1, 'that': 242, 'curiosity': 3, 'neither': 7, 'can': 36, 'make': 46, 'choice': 4, 'eithers': 1, 'moiety': 1, 'Is': 27, 'this': 181, 'your': 202, 'my': 396, 'lord': 96, 'His': 19, 'breeding': 3, 'sir': 87, 'hath': 52, 'been': 29, 'at': 54, 'charge': 3, 'have': 187, 'often': 3, 'blushed': 1, 'acknowledge': 2, 'him': 195, 'am': 84, 'brazed': 1, 't': 48, 'cannot': 19, 'conceive': 1, 'you': 396, 'Sir': 21, 'young': 10, 'fellows': 3, 'mother': 4, 'could': 17, 'whereupon': 1, 'she': 39, 'grew': 3, 'round-wombed': 1, 'indeed': 5, 'cradle': 1, 'ere': 5, 'bed': 7, 'Do': 24, 'smell': 6, 'fault': 8, 'wish': 2, 'undone': 1, 'issue': 4, 'being': 15, 'proper': 1, 'But': 56, 'order': 1, 'law': 4, 'some': 26, 'year': 4, 'who': 31, 'yet': 41, 'is': 196, 'no': 93, 'dearer': 3, 'account': 1, 'Though': 8, 'knave': 18, 'came': 13, 'something': 7, 'saucily': 2, 'world': 19, 'before': 15, 'was': 47, 'sent': 5, 'fair': 9, 'there': 43, 'good': 62, 'sport': 3, 'making': 3, 'whoreson': 5, 'must': 44, 'be': 143, 'acknowledged': 2, 'know': 75, 'noble': 18, 'Edmund': 35, 'No': 59, 'My': 60, 'Kent': 23, 'Remember': 3, 'hereafter': 1, 'as': 93, 'honorable': 2, 'friend': 18, 'services': 5, 'Lordship': 3, 'love': 48, 'sue': 1, 'better': 26, 'shall': 83, 'study': 3, 'deserving': 2, 'He': 54, 'out': 58, 'nine': 1, 'years': 6, 'away': 28, 'again': 19, 'The': 138, 'coming': 8, 'Enter': 14, 'Goneril': 14, 'Regan': 24, 'Cordelia': 28, 'Attend': 1, 'lords': 7, 'France': 24, 'Burgundy': 13, 'Gloucester': 27, 'Meantime': 1, 'we': 59, 'express': 2, 'our': 95, 'darker': 1, 'purpose': 11, 'Give': 22, 'me': 225, 'map': 1, 'Know': 4, 'divided': 1, 'In': 31, 'three': 4, 'tis': 19, 'fast': 2, 'intent': 6, 'To': 116, 'shake': 7, 'all': 83, 'cares': 2, 'business': 14, 'age': 11, 'Conferring': 1, 'them': 48, 'strengths': 1, 'while': 2, 'Unburdened': 1, 'crawl': 1, 'toward': 11, 'death': 18, 'Our': 21, 'And': 155, 'less': 18, 'loving': 2, 'We': 17, 'hour': 5, 'constant': 2, 'will': 114, 'publish': 1, 'daughters': 28, 'several': 2, 'dowers': 2, 'future': 1, 'strife': 2, 'May': 9, 'prevented': 1, 'two': 21, 'great': 27, 'princes': 2, 'Great': 2, 'rivals': 1, 'Long': 1, 'court': 4, 'made': 20, 'their': 57, 'amorous': 1, 'sojourn': 3, 'here': 50, 'answered': 2, 'Tell': 4, 'Since': 5, 'divest': 1, 'both': 16, 'rule': 2, 'Interest': 1, 'territory': 1, 'state': 12, 'Which': 37, 'say': 30, 'doth': 14, 'That': 98, 'largest': 1, 'bounty': 2, 'may': 44, 'extend': 1, 'Where': 23, 'nature': 32, 'merit': 2, 'challenge': 3, 'born': 4, 'speak': 33, 'first': 17, 'word': 13, 'wie ...
# {'the': 661, 'I': 614, 'and': 542, 'of': 446, 'to': 410, 'you': 396, 'my': 396, 'a': 325, 'in': 267, 'not': 261, 'that': 242, 'me': 225, 'your': 202, 'is': 196, 'him': 195, 'have': 187, 'his': 182, 'this': 181, 'with': 168, 'thou': 164, 'it': 163, 'And': 155, 'be': 143, 'The': 138, 'thy': 137, 'thee': 134, 'her': 128, 'he': 119, 'To': 116, 'will': 114, 'are': 114, 'for': 114, 'so': 101, 'That': 98, 'on': 98, 'lord': 96, 'our': 95, 'as': 93, 'no': 93, 'do': 91, 'sir': 87, 'What': 85, 'am': 84, 'all': 83, 'shall': 83, 'th': 82, 'from': 81, 'If': 78, 'more': 76, 'know': 75, 'but': 71, 'Ill': 70, 'You': 69, 'by': 67, 'O': 66, 'father': 64, 'good': 62, 'man': 61, 'well': 60, 'My': 60, 'we': 59, 'No': 59, 'out': 58, 'their': 57, 'Thou': 56, 'This': 56, 'But': 56, 'He': 54, 'at': 54, 'would': 53, 'hath': 52, 'us': 52, 'what': 51, 'than': 51, 'here': 50, 'take': 49, 'or': 49, 'see': 48, 'Come': 48, 'them': 48, 'love': 48, 't': 48, 'now': 48, 'A': 48, 'How': 47, 'was': 47, 'make': 46, 'which': 46, 'old': 45, 'heart': 45, 'they': 44, 'may': 44, 'must': 44, 'Let': 43, 'there': 43, 'most': 42, 'King': 42, 'yet': 41, 'eyes': 40, 'When': 40, 'like': 40, 'should': 39, 'such': 39, 'Why': 39, 'come': 39, 'she': 39, 'art': 38, 'when': 38, 'upon': 37, 'Which': 37, 'For': 36, 'can': 36, 'go': 35, 'Who': 35, 'So': 35, 'Edmund': 35, 'had': 35, 'Tis': 34, 'let': 34, 'if': 34, 'life': 34, 'speak': 33, 'one': 32, 'an': 32, 'nature': 32, 'daughter': 32, 'poor': 31, 'In': 31, 'who': 31, 'night': 30, 'too': 30, 'With': 30, 'these': 30, 'say': 30, 'then': 30, 'Now': 29, 'sister': 29, 'much': 29, 'been': 29, 'son': 29, 'Fool': 28, 'time': 28, 'up': 28, 'daughters': 28, 'Cordelia': 28, 'away': 28, 'were': 27, 'nor': 27, 'As': 27, 'great': 27, 'Gloucester': 27, 'Is': 27, 'king': 27, 'madam': 26, 'own': 26, 'tell': 26, 'never': 26, 'hand': 26, 'better': 26, 'some': 26, 'fellow': 25, 'way': 25, 'gods': 25, 'master': 25, 'nothing': 25, 'It': 25, 'letter': 24, 'i': 24, 'place': 24, 'thine': 24, 'France': 24, 'Regan': 24, 'Do': 24, 'Go': 23, 'other': 23, 'Where': 23, 'Kent': 23, 'thus': 22, 'hear': 22, 'best': 22, 'By': 22, 'Thy': 22, 'how': 22, 'comes': 22, 'Give': 22, 'Lear': 22, 'o': 21, 'Your': 21, 'where': 21, 'hast': 21, 'very': 21, 'Of': 21, 'two': 21, 'Our': 21, 'Sir': 21, 'mine': 20, 'think': 20, 'dost': 20, 'give': 20, 'Good': 20, 'made': 20, 'fiend': 19, 'head': 19, 'down': 19, 'All': 19, 'dear': 19, 'Be': 19, 'tis': 19, 'again': 19, 'world': 19, 'cannot': 19, 'His': 19, 'hold': 18, 'against': 18, 'Ay': 18, 'Then': 18, 'lady': 18, 'less': 18, 'death': 18, 'friend': 18, 'noble': 18, 'knave': 18, 'did': 18, 'Duke': 18, 'Poor': 17, 'fool': 17, 'villain': 17, 'brother': 17, 'Not': 17, 'Will': 17, 'mad': 17, 'into': 17, 'first': 17, 'We': 17, 'could': 17, 'house': 16, 'boy': 16, 'Tom': 16, 'itself': 16, 'Well': 16, 'Take': 16, 'still': 16, 'power': 16, 'set': 16, 'Or': 16, 'little': 16, 'whose': 16, 'Than': 16, 'Speak': 16, 'both': 16, 'sword': 15, 'hither': 15, 'men': 15, 'put': 15, 'done': 15, 'off': 15, 'call': 15, 'Have': 15, 'answer': 15, 'foul': 15, 'Here': 15, 'sisters': 15, 'find': 15, 'matter': 15, 'before': 15, 'being': 15, 'Cornwall': 15, 'dead': 14, 'traitor': 14, 'use': 14, 'fire': 14, 'nuncle': 14, 'stand': 14, 'Shall': 14, 'Pray': 14, 'There': 14, 'bring': 14, 'look': 14, 'She': 14, 'bear': 14, 'fear': 14, 'does': 14, 'though': 14, 'name': 14, 'course': 14, 'They': 14, 'since': 14, 'doth': 14, 'business': 14, 'Goneril': 14, 'Enter': 14, 'mans': 13, 'forth': 13, 's': 13, 'slave': 13, 'keep': 13, 'seen': 13, 'means': 13, 'after': 13, 'any': 13, 'live': 13, 'till': 13, 'seek': 13, 'gone': 13, 'thing': 13, 'From': 13, 'makes': 13, 'word': 13, 'Burgundy': 13, 'came': 13, 'thought': 13, 'cause': 12, 'long': 12, 'pray': 12, 'wind': 12, 'heard': 12, 'Edgar': 12, 'mind': 12, 'further': 12, 'reason': 12, 'many': 12, 'Upon': 12, 'Nor': 12, 'part': 12, 'turn': 12, 'fathers': 12, 'kind': 12, 'blood': 12, 'back': 12, 'ever': 12, 'true': 12, 'even': 12, 'st ...

# %% [markdown]
# ### [Part 2 20pts] Looking for common patterns of language across pairs of documents in a corpus (text collection)
# Here we have several other Shakespear plays that we can analysis. In Part1 we loaded King Lear, now we will load Merchant of Venice [all plays can be found here](https://www.folger.edu/explore/shakespeares-works/).

# %%
merchant = read_and_process_text('the_merchant_of_venice_shakespeare.txt')
merchant[:1000]
# Out:
# 'The Merchant of Venice by William Shakespeare Edited by Barbara A Mowat and Paul Werstine with Michael Poston and Rebecca Niles Folger Shakespeare Library https//shakespeare folger edu/shakespeares-works/the-merchant-of-venice/ Created on Jul 31 2015 from FDT version 0 9 2 Characters in the Play an heiress of Belmont her waiting-gentlewoman Servants to Portia BALTHAZAR STEPHANO Suitors to Portia Prince of MOROCCO Prince of ARRAGON a merchant of Venice a Venetian gentleman suitor to Portia Companions of Antonio and Bassanio SOLANIO SALARINO GRATIANO LORENZO servant to Bassanio a Jewish moneylender in Venice his daughter another Jewish moneylender GOBBO servant to Shylock and later to Bassanio GOBBO Lancelets father a messenger from Venice Jailer Duke of Venice Magnificoes of Venice Servants Attendants and followers Messenger Musicians In sooth I know not why I am so sad It wearies me you say it wearies you But how I caught it found it or came by it What stuff tis made of whereof it is b'

# %% [markdown]
# Two important things we may want to know here are what are the common words and what are the words that are unique to each play. In other words what words do these play share? What words are unique to each play? Before you begin coding, take a look through the text files which are designed to be human readable texts and think critically about this question.

# %% [markdown]
# #### [Exercise 2a] Human Read and guess common/unique words
#
# Here you will simply read each text (King Lear and Merchant of Venice) for around 5-10 minutes and brain storm some ideas of which words you think will be common and which will be unique. You can use the python lists that are started below to put at least 10 of your ideas for each.

# %%
#Exercise 2a ideas here using human reading only!!!

common = ["I", "my", "and", "is", "am", "of", "was", "the", "will", "it", "us"] 
unique = ["Regan", "Cordeila", "Bassanio", "Gratiano", "Antonio", "Sibylla", "Edmund", "Shylock", "Morocco", "Lancelet", "Kent"]

# %% [markdown]
# #### [Exercise 2b] Looking for patterns using our dictionary (and python3 skills)
# Now do the same thing as above but write a program to do it you can use the idea shown below which will demonstrate how to find the common characters of two strings as well as those characters that are unique to each string. Another name for common elements of two sets is called set intersection: $S\bigcap T$, while the elements unique to S given T is called set difference: $S\setminus T$, while the elements unique to T given S is: $T\setminus S$. Notice how the set difference is non-symmetric, the set on the left hand side gets any intersected elements with T removed.

# %%
#find common chars of two strings s and t
s = "Hello world how are you? I am fine of course, for now..."
t = "This COM110 class sure is fun!"

union  = sorted(set(s).union(set(t)))
inter  = sorted(set(s).intersection(set(t)))
s_diff = sorted(set(s).difference(set(t)))
t_diff = sorted(set(t).difference(set(s)))

print(union)
print(inter)
print(s_diff)
print(t_diff)
# Out:
# [' ', '!', ',', '.', '0', '1', '?', 'C', 'H', 'I', 'M', 'O', 'T', 'a', 'c', 'd', 'e', 'f', 'h', 'i', 'l', 'm', 'n', 'o', 'r', 's', 'u', 'w', 'y']
# [' ', 'a', 'c', 'e', 'f', 'h', 'i', 'l', 'n', 'r', 's', 'u']
# [',', '.', '?', 'H', 'I', 'd', 'm', 'o', 'w', 'y']
# ['!', '0', '1', 'C', 'M', 'O', 'T']

# %%
# Exercise 2b Answer
m = merchant.split(" ") # Splitting the merchant text by spaces to store words
l = lear.split(" ")     # Splitting the lear text by spaces to store words

union = sorted(set(m).union(set(l)))        # Finding the union of two texts
inter = sorted(set(m).intersection(set(l))) # Finding the intersection of two texts
m_diff = sorted(set(m).difference(set(l)))  # Finding the values that are unique to merchant
l_diff = sorted(set(l).difference(set(m)))  # Finding the values that are unique to lear

# Printing the results
print(union)
print(inter)
print(m_diff)
print(l_diff)
# Out:
# ['', '0', '2', '2015', '31', '9', 'A', 'ALBANY', 'ALLDing', 'ARRAGON', 'Abhorred', 'Abominable', 'About', 'Above', 'Abram', 'According', 'Achieved', 'Acquaint', 'Adieu', 'Adultery', 'Advise', 'Aeson', 'Affliction', 'After', 'Again', 'Against', 'Age', 'Ah', 'Ajax', 'Alack', 'Alarum', 'Alas', 'Albany', 'Albanys', 'Albeit', 'Albion', 'Alcides', 'Alive', 'All', 'Allow', 'Allows', 'Alls', 'Almost', 'Along', 'Aloof', 'Alow', 'Although', 'Am', 'Among', 'An', 'And', 'Andrew', 'Angring', 'Another', 'Answer', 'Antipodes', 'Antonio', 'AntonioO', 'Antonios', 'Apollo', 'Appear', 'Approach', 'April', 'Arabia', 'Are', 'Argus', 'Arm', 'Armed', 'Arms', 'Arragon', 'Arraign', 'Art', 'As', 'Ash', 'Ask', 'At', 'Athenian', 'Attend', 'Attendant', 'Attendants', 'Authority', 'Avaunt', 'Away', 'Ay', 'BALTHAZAR', 'BURGUNDY', 'Back', 'Bad', 'Balthazar', 'Barabbas', 'Barbara', 'Barbary', 'Bars', 'Bassanio', 'Bassanioas', 'Bassanios', 'Bastard', 'Be', 'Bear', 'Beat', 'Because', 'Become', 'Bedlam', 'Been', 'Before', 'Beg', 'Began', 'Behold', 'Being', 'Believe', 'Belike', 'Bellario', 'Bellarios', 'Belmont', 'Beloved', 'Bemonster', 'Bench', 'Beshrew', 'Besides', 'Bespeak', 'Bessy', 'Bethink', 'Better', 'Between', 'Beware', 'Beweep', 'Beyond', 'Bid', 'Bids', 'Bind', 'Black', 'Blanch', 'Blanket', 'Blasts', 'Bless', 'Blow', 'Blows', 'Bobtail', 'Bold', 'Bon', 'Bore', 'Both', 'Brach', 'Break', 'Briefly', 'Briefness', 'Bring', 'Bringing', 'Britain', 'British', 'Brother', 'Brought', 'Brutus', 'Budge', 'Builds', 'Burgundy', 'Burn', 'Burst', 'But', 'By', 'CORNWALL', 'Caitiff', 'Caius', 'Call', 'Came', 'Camelot', 'Can', 'Cannot', 'Canst', 'Captain', 'Carthage', 'Catch', 'Catos', 'Certainly', 'Chance', 'Change', 'Characters', 'Charybdis', 'Child', 'Chill', 'Christian', 'Christians', 'Chus', 'Clamber', 'Clerk', 'Close', 'Clown', 'Colchos', 'Cold', 'Colors', 'Combine', 'Come', 'Comes', 'Coming', 'Commanded', 'Commend', 'Commends', 'Commit', 'Commits', 'Companions', 'Conceive', 'Conferring', 'Confess', 'Confined', 'Conscience', 'Consider', 'Consisteth', 'Conspiracy', 'Conspirant', 'Contending', 'Content', 'Convey', 'Cordelia', 'Cornwall', 'Cornwalls', 'Corruption', 'Cost', 'Could', 'Couldst', 'Count', 'County', 'Cover', 'Crack', 'Create', 'Created', 'Creep', 'Cressid', 'Cried', 'Croak', 'Crowned', 'Cry', 'Crying', 'Cunning', 'Cupid', 'Cupids', 'Curan', 'Cure', 'Cursed', 'Daniel', 'Dardanian', 'Darkness', 'Darnel', 'Darst', 'Dear', 'Dearer', 'Death', 'Decline', 'Defy', 'Degenerate', 'Deliver', 'Delivered', 'Denied', 'Deny', 'Descend', 'Deserved', 'Desire', 'Desired', 'Despite', 'Destinies', 'Detains', 'Detested', 'Diana', 'Did', 'Dido', 'Didst', 'Die', 'Diminished', 'Ding', 'Dinner', 'Directly', 'Disguise', 'Dismissing', 'Displayed', 'Dispose', 'Do', 'Dobbin', 'Dobbins', 'Doctor', 'Does', 'Dogs', 'Dolphin', 'Dost', 'Doth', 'Double', 'Dover', 'Dowered', 'Down', 'Dragons', 'Draw', 'Drew', 'Drones', 'Drops', 'Drum', 'Dry', 'Duchess', 'Duke', 'Dukes', 'During', 'Dwells', 'Each', 'Earl', 'Earth', 'Edgar', 'Edited', 'Edmund', 'Effects', 'Either', 'Election', 'Else', 'Empties', 'Endymion', 'Enforce', 'Engaged', 'England', 'English', 'Englishman', 'Enough', 'Enow', 'Enrobe', 'Enter', 'Entered', 'Entreat', 'Epicurism', 'Ere', 'Erebus', 'Ergo', 'Escaped', 'Even', 'Every', 'Everyone', 'Exact', 'Exasperates', 'Exceed', 'Except', 'Expose', 'Expressed', 'FDT', 'FOOLThat', 'FRANCE', 'Fa', 'Fading', 'Fair', 'Fairest', 'Fairies', 'Faith', 'Falconbridge', 'Fall', 'False', 'Far', 'Fare', 'Farewell', 'Fast', 'Faster', 'Fates', 'Father', 'Fathers', 'Fathom', 'Fear', 'Fed', 'Feel', 'Fellow', 'Fellows', 'Fetch', 'Fetching', 'Few', 'Fia', 'Fie', 'Fiend', 'Fiery', 'Filial', 'Filths', 'Find', 'Fine', 'First', 'Five', 'Fled', 'Fleece', 'Flew', 'Flibbertigibbet', 'Flourish', 'Fly', 'Folger', 'Follow', 'Followed', 'Fool', 'Fools', 'For', 'Forced', 'Forget', 'Forgive', 'Fortune', 'Fortunes', 'Fought', 'Found', 'Fourscore', 'Frame', 'France', 'Frankfurt', 'Frateretto', 'Freedom', 'French', 'Frenchman', ' ...
# ['', '0', '2', '2015', '31', '9', 'A', 'About', 'Above', 'Alack', 'Alas', 'All', 'An', 'And', 'Answer', 'Approach', 'Are', 'Art', 'As', 'At', 'Attendants', 'Away', 'Ay', 'Barbara', 'Be', 'Because', 'Before', 'Beg', 'Behold', 'Being', 'Besides', 'Bid', 'Bring', 'But', 'By', 'Call', 'Came', 'Can', 'Cannot', 'Characters', 'Come', 'Commend', 'Could', 'Created', 'Cupid', 'Dear', 'Descend', 'Deserved', 'Did', 'Didst', 'Do', 'Doctor', 'Doth', 'Down', 'Draw', 'Duke', 'Earth', 'Edited', 'English', 'Enter', 'Ere', 'Even', 'Every', 'FDT', 'Fair', 'Fall', 'Fare', 'Farewell', 'Father', 'Fie', 'Find', 'First', 'Fled', 'Fly', 'Folger', 'Follow', 'For', 'Fortune', 'Fourscore', 'France', 'Friend', 'From', 'Gentle', 'Gentlemen', 'Germany', 'Get', 'Give', 'Go', 'Gods', 'Good', 'Grace', 'Graces', 'Ha', 'Had', 'Hang', 'Hard', 'Hast', 'Hath', 'Have', 'Having', 'He', 'Hear', 'Hearing', 'Heaven', 'Her', 'Here', 'Heres', 'Himself', 'His', 'Ho', 'Hold', 'Honor', 'How', 'I', 'If', 'Ill', 'In', 'Into', 'Is', 'It', 'Jul', 'Know', 'Leave', 'Let', 'Lets', 'Library', 'Like', 'Look', 'Lord', 'Lordship', 'Love', 'Madam', 'Make', 'Mark', 'Marry', 'Masters', 'May', 'Meantime', 'Men', 'Methinks', 'Michael', 'Mine', 'Monsieur', 'More', 'Most', 'Mowat', 'Must', 'My', 'Myself', 'Nature', 'Nay', 'Neither', 'Never', 'Niles', 'No', 'None', 'Nor', 'Not', 'Nothing', 'Now', 'O', 'Of', 'Often', 'On', 'One', 'Only', 'Or', 'Our', 'Out', 'Over', 'Pardon', 'Parted', 'Past', 'Paul', 'Persian', 'Peruse', 'Phoebus', 'Play', 'Pluck', 'Poston', 'Pray', 'Prince', 'Prove', 'Queen', 'Ready', 'Rebecca', 'Repair', 'Report', 'Return', 'Say', 'See', 'Seem', 'Send', 'Servants', 'Shakespeare', 'Shall', 'She', 'Should', 'Shut', 'Since', 'Sir', 'Sirrah', 'Sisters', 'Sit', 'Sleep', 'So', 'Some', 'Something', 'Speak', 'Still', 'Such', 'Sweet', 'Take', 'Talk', 'Tell', 'Than', 'That', 'Thats', 'The', 'Their', 'Then', 'There', 'Therefore', 'Theres', 'These', 'They', 'This', 'Those', 'Thou', 'Though', 'Three', 'Thus', 'Thy', 'Till', 'Tis', 'To', 'Tomorrow', 'Too', 'True', 'Truly', 'Turn', 'Twill', 'Until', 'Upon', 'Use', 'Very', 'Was', 'We', 'Wear', 'Well', 'Were', 'Werstine', 'What', 'Whats', 'When', 'Where', 'Wherein', 'Whereof', 'Wheres', 'Which', 'Whiles', 'Whither', 'Who', 'Whom', 'Whos', 'Whose', 'Why', 'Will', 'William', 'Wilt', 'With', 'Within', 'Without', 'Would', 'Wouldst', 'Yea', 'Yes', 'Yet', 'You', 'Your', 'a', 'able', 'abode', 'about', 'above', 'abroad', 'account', 'acknowledge', 'acquaintance', 'act', 'add', 'adieu', 'ado', 'advantage', 'advantages', 'adversary', 'advice', 'advised', 'affairs', 'affection', 'after', 'again', 'against', 'age', 'air', 'alas', 'alive', 'all', 'allay', 'almost', 'alone', 'along', 'already', 'always', 'am', 'amazed', 'amity', 'among', 'amorous', 'an', 'ancient', 'and', 'angel', 'anon', 'another', 'answer', 'answered', 'any', 'anything', 'appear', 'appears', 'appetite', 'apple', 'approach', 'approve', 'are', 'armed', 'army', 'art', 'as', 'ashamed', 'ask', 'aspect', 'asses', 'assume', 'assured', 'at', 'attend', 'attended', 'aught', 'authority', 'away', 'ay', 'back', 'bad', 'bags', 'bar', 'barbarous', 'bare', 'bark', 'base', 'bastard', 'bay', 'be', 'beach', 'beams', 'bear', 'beard', 'bearing', 'bears', 'beast', 'beaten', 'beauty', 'became', 'become', 'becomes', 'bed', 'been', 'before', 'beg', 'beggar', 'begged', 'begin', 'begone', 'begot', 'behavior', 'behind', 'behold', 'beholding', 'being', 'believe', 'belly', 'beloved', 'bend', 'beneath', 'beseech', 'best', 'bestow', 'bestowed', 'better', 'between', 'beware', 'bid', 'bidding', 'bids', 'big', 'bind', 'bird', 'birth', 'blame', 'bleed', 'bless', 'blessing', 'blest', 'blind', 'bliss', 'blood', 'bloody', 'blow', 'body', 'bold', 'bond', 'bones', 'books', 'bootless', 'born', 'borne', 'borrow', 'bosom', 'bosoms', 'both', 'bound', 'bounds', 'bounty', 'bow', 'boy', 'boys', 'braggart', 'brain', 'brave', 'break', 'breath', 'bred', 'breed', 'breeding', 'brief', 'bring', 'brothers', 'brought', 'brow', 'burning', 'busin ...
# ['ALLDing', 'ARRAGON', 'Abram', 'Achieved', 'Adieu', 'Aeson', 'After', 'Albeit', 'Alcides', 'Among', 'Andrew', 'Antipodes', 'Antonio', 'AntonioO', 'Antonios', 'April', 'Arabia', 'Argus', 'Arragon', 'Ash', 'BALTHAZAR', 'Balthazar', 'Barabbas', 'Barbary', 'Bars', 'Bassanio', 'Bassanioas', 'Bassanios', 'Become', 'Believe', 'Bellario', 'Bellarios', 'Belmont', 'Beshrew', 'Bespeak', 'Between', 'Black', 'Bon', 'Brutus', 'Budge', 'Builds', 'Carthage', 'Catos', 'Certainly', 'Chance', 'Charybdis', 'Christian', 'Christians', 'Chus', 'Clamber', 'Clerk', 'Clown', 'Colchos', 'Cold', 'Comes', 'Commends', 'Commits', 'Companions', 'Confess', 'Conscience', 'Consisteth', 'Content', 'Count', 'County', 'Creep', 'Cressid', 'Crying', 'Cupids', 'Cursed', 'Daniel', 'Dardanian', 'Defy', 'Deliver', 'Desired', 'Destinies', 'Diana', 'Dido', 'Ding', 'Directly', 'Disguise', 'Dobbin', 'Dobbins', 'Double', 'Drones', 'Drops', 'Empties', 'Endymion', 'Engaged', 'England', 'Englishman', 'Enow', 'Enrobe', 'Entered', 'Entreat', 'Erebus', 'Ergo', 'Exact', 'Exceed', 'Except', 'Expressed', 'Fading', 'Falconbridge', 'Fast', 'Faster', 'Fates', 'Fed', 'Fetching', 'Fia', 'Fiend', 'Fleece', 'Forget', 'Forgive', 'Frankfurt', 'French', 'Frenchman', 'Furthermore', 'GOBBO', 'GRATIANO', 'Garnished', 'Gave', 'Genoa', 'German', 'Giddy', 'Gifts', 'Gilded', 'Glancing', 'Gobbo', 'God', 'Gold', 'Goodly', 'Goodwins', 'Governed', 'Grant', 'Gratiano', 'Gratianos', 'Grecian', 'Grieve', 'Hagars', 'Handing', 'Hanging', 'Happiest', 'Happy', 'Hate', 'Hates', 'Hazard', 'Hebrew', 'Hercules', 'Hiding', 'Hie', 'Hugged', 'Hyrcanian', 'Immediately', 'Indeed', 'India', 'Indian', 'Indies', 'Infused', 'Inquire', 'Issuing', 'Italian', 'Italy', 'Jacob', 'Jacobs', 'Jailer', 'Janus', 'Jasons', 'Jessica', 'Jew', 'Jewess', 'Jewish', 'Jews', 'Joy', 'Justice', 'LORENZO', 'Laban', 'Labans', 'Ladyship', 'Lancelet', 'Lancelets', 'Lastly', 'Latin', 'Le', 'Leah', 'Lean', 'Leonardo', 'Lie', 'Lies', 'Lisbon', 'Live', 'Lock', 'Lorenzo', 'LorenzoJessica', 'Lychas', 'MOROCCO', 'Magnificoes', 'Making', 'Many', 'Margery', 'Marquess', 'Mars', 'Master', 'Medea', 'Meet', 'Meetest', 'Merchant', 'Messenger', 'Methoughts', 'Mexico', 'Midas', 'Misfortune', 'Mislike', 'Miss', 'Mistress', 'Monday', 'Moneys', 'Montferrat', 'Moor', 'Morocco', 'Move', 'Music', 'Musicians', 'Narrow', 'Nazarite', 'Neapolitan', 'Neapolitans', 'Nearest', 'Negros', 'Nerissa', 'Nerissas', 'Nestor', 'New', 'Notwithstanding', 'Obscures', 'Oracle', 'Orpheus', 'Outbrave', 'Padua', 'Palatine', 'Parts', 'Patiently', 'Pawned', 'Pay', 'Peacehow', 'Perhaps', 'Picked', 'Piring', 'Plucking', 'Portia', 'Portias', 'Presenting', 'Proceed', 'Promise', 'Puts', 'Pythagoras', 'Quick', 'Ran', 'Rating', 'Rebels', 'Renowned', 'Repent', 'Reply', 'Rest', 'Revenge', 'Rhenish', 'Rialto', 'Roman', 'Rome', 'SALARINO', 'SOLANIO', 'STEPHANO', 'Sabbath', 'Salerio', 'Saxonys', 'Scottish', 'Scripture', 'Scylla', 'Seas', 'Seasthe', 'Serve', 'Seven', 'Shed', 'Shylock', 'Shylocks', 'Sibylla', 'Signior', 'Silence', 'Silvered', 'Slander', 'Slubber', 'Snail-slow', 'Soft', 'Sola', 'Solanio', 'Solyman', 'Sometimes', 'Sophy', 'Spets', 'Stamped', 'Stealing', 'Stephano', 'Stoln', 'Stood', 'Straight', 'Suitors', 'Sultan', 'Superfluity', 'Supply', 'Swear', 'Tarry', 'Tartars', 'Tears', 'Thanks', 'Thisbe', 'Thyself', 'Tripolis', 'Troilus', 'Trojan', 'Troy', 'Truth', 'Try', 'Tubal', 'Turks', 'Turning', 'Turns', 'Tween', 'Twenty', 'Twere', 'Two', 'Uncapable', 'Uncle', 'Unless', 'Unseal', 'Unto', 'Vailing', 'Veiling', 'Venetian', 'Venice', 'Venus', 'Waste', 'Watch', 'Wednesday', 'Whether', 'Wo', 'Worship', 'Worships', 'Wrest', 'Yonder', 'Youll', 'Young', 'Yourself', 'a-bleeding', 'a-brewing', 'a-capring', 'abate', 'abide', 'abject', 'aboard', 'abridged', 'absence', 'absent', 'abundance', 'accept', 'acceptance', 'accepted', 'accident', 'accomplished', 'according', 'accordingly', 'accoutered', 'accused', 'acquainted', 'acquitted', 'addressed', 'admit', 'adventuring', 'advisedly', 'afeard', 'affections', ' ...
# ['ALBANY', 'Abhorred', 'Abominable', 'According', 'Acquaint', 'Adultery', 'Advise', 'Affliction', 'Again', 'Against', 'Age', 'Ah', 'Ajax', 'Alarum', 'Albany', 'Albanys', 'Albion', 'Alive', 'Allow', 'Allows', 'Alls', 'Almost', 'Along', 'Aloof', 'Alow', 'Although', 'Am', 'Angring', 'Another', 'Apollo', 'Appear', 'Arm', 'Armed', 'Arms', 'Arraign', 'Ask', 'Athenian', 'Attend', 'Attendant', 'Authority', 'Avaunt', 'BURGUNDY', 'Back', 'Bad', 'Bastard', 'Bear', 'Beat', 'Bedlam', 'Been', 'Began', 'Belike', 'Beloved', 'Bemonster', 'Bench', 'Bessy', 'Bethink', 'Better', 'Beware', 'Beweep', 'Beyond', 'Bids', 'Bind', 'Blanch', 'Blanket', 'Blasts', 'Bless', 'Blow', 'Blows', 'Bobtail', 'Bold', 'Bore', 'Both', 'Brach', 'Break', 'Briefly', 'Briefness', 'Bringing', 'Britain', 'British', 'Brother', 'Brought', 'Burgundy', 'Burn', 'Burst', 'CORNWALL', 'Caitiff', 'Caius', 'Camelot', 'Canst', 'Captain', 'Catch', 'Change', 'Child', 'Chill', 'Close', 'Colors', 'Combine', 'Coming', 'Commanded', 'Commit', 'Conceive', 'Conferring', 'Confined', 'Consider', 'Conspiracy', 'Conspirant', 'Contending', 'Convey', 'Cordelia', 'Cornwall', 'Cornwalls', 'Corruption', 'Cost', 'Couldst', 'Cover', 'Crack', 'Create', 'Cried', 'Croak', 'Crowned', 'Cry', 'Cunning', 'Curan', 'Cure', 'Darkness', 'Darnel', 'Darst', 'Dearer', 'Death', 'Decline', 'Degenerate', 'Delivered', 'Denied', 'Deny', 'Desire', 'Despite', 'Detains', 'Detested', 'Die', 'Diminished', 'Dinner', 'Dismissing', 'Displayed', 'Dispose', 'Does', 'Dogs', 'Dolphin', 'Dost', 'Dover', 'Dowered', 'Dragons', 'Drew', 'Drum', 'Dry', 'Duchess', 'Dukes', 'During', 'Dwells', 'Each', 'Earl', 'Edgar', 'Edmund', 'Effects', 'Either', 'Election', 'Else', 'Enforce', 'Enough', 'Epicurism', 'Escaped', 'Everyone', 'Exasperates', 'Expose', 'FOOLThat', 'FRANCE', 'Fa', 'Fairest', 'Fairies', 'Faith', 'False', 'Far', 'Fathers', 'Fathom', 'Fear', 'Feel', 'Fellow', 'Fellows', 'Fetch', 'Few', 'Fiery', 'Filial', 'Filths', 'Fine', 'Five', 'Flew', 'Flibbertigibbet', 'Flourish', 'Followed', 'Fool', 'Fools', 'Forced', 'Fortunes', 'Fought', 'Found', 'Frame', 'Frateretto', 'Freedom', 'Friends', 'Full', 'Fut', 'GLOUCESTER', 'Gainst', 'Gallow', 'General', 'Gentleman', 'Gloucester', 'Gloucesters', 'Gone', 'Goneril', 'Goose', 'Got', 'Govern', 'Gracious', 'Great', 'Hadst', 'Hail', 'Half', 'Half-blooded', 'Halfway', 'Hangs', 'Haply', 'Harbor', 'Harder', 'Hark', 'Has', 'Haste', 'Hasten', 'Hearty', 'Heavens', 'Hecate', 'Hell', 'Help', 'Hence', 'Henceforth', 'Hes', 'Hewgh', 'Hide', 'Highness', 'Hill', 'Hobbididance', 'Holds', 'Holla', 'Honors', 'Hoppedance', 'Horns', 'Horrible', 'Horse', 'Horses', 'Hot', 'Hound', 'Howeer', 'Howl', 'Hows', 'Hum', 'Humanity', 'Hush', 'Hysterica', 'Id', 'Idle', 'Im', 'Importune', 'Improper', 'Infect', 'Infirmity', 'Inform', 'Informed', 'Ingrateful', 'Ingratitude', 'Instantly', 'Intelligence', 'Intelligent', 'Interest', 'Invades', 'Ise', 'Jesters', 'Jove', 'Judicious', 'Jug', 'Juno', 'Jupiter', 'KENT', 'KENTBy', 'Keep', 'Kent', 'Kents', 'Kill', 'Kind', 'King', 'Kingin', 'Knights', 'Knowing', 'Knowledge', 'Knows', 'Knowst', 'LEARCome', 'La', 'Lady', 'Lag', 'Late', 'Lay', 'Lear', 'Learn', 'Lears', 'Leaving', 'Led', 'Legitimate', 'Lend', 'Lending', 'Lest', 'Life', 'Light', 'Lipsbury', 'List', 'Long', 'Looked', 'Looks', 'Losses', 'Lost', 'Louder', 'Loved', 'Loves', 'Loyal', 'Lurk', 'MAN', 'Machinations', 'Made', 'Madman', 'Mahu', 'Majesty', 'Major', 'Makes', 'Makst', 'Mans', 'Marshal', 'Mastiff', 'Maugre', 'Maybe', 'Mean', 'Mend', 'Mere', 'Merlin', 'Met', 'Methought', 'Might', 'Milk-livered', 'Miscreant', 'Modo', 'Monster', 'Mum', 'Mumbling', 'Murder', 'Natures', 'Naughty', 'Near', 'Necessitys', 'Neer', 'Nero', 'NeverO', 'News', 'Noble', 'Nuncle', 'OF', 'Obey', 'Obidicut', 'Occasions', 'OfO', 'Off', 'Officers', 'Oho', 'Old', 'Opposed', 'Oppressed', 'Oswald', 'Ourself', 'Owes', 'Pantingly', 'Part', 'Pass', 'Patience', 'Peace', 'Persuade', 'Pierce', 'Pillicock', 'Pinion', 'Pins', 'Plate', 'Please', 'Poor', 'Post', 'Pour', 'Preemine ...

# %% [markdown]
# ### [Part 3] More advanced text processing. Removing super common words: stoplist
#
# Now we will construct a set of the most common words across all the texts in the interest of solving the following problem: Given several text from multiple authors, what are the most common words? In other words, we will build a word frequency function and then subtract the high frequency words from a text we want to analyze. What will be left will be words that are more descriptive and unique to the source.

# %%
#example frequency counting functionadapted from part 1 for chars in a string
def freq(s):
    D = {}
    for x in s:
        if x in D: D[x] += 1
        else:      D[x]  = 1
    return {k:D[k] for k in sorted(D,key=lambda x: D[x])[::-1]}

pride = read_and_process_text('pride_and_prejudice.txt')
pride[:1000]
# Out:
# 'The Project Gutenberg eBook of Pride and Prejudice This ebook is for the use of anyone anywhere in the United States and most other parts of the world at no cost and with almost no restrictions whatsoever You may copy it give it away or re-use it under the terms of the Project Gutenberg License included with this ebook or online at www gutenberg org If you are not located in the United States you will have to check the laws of the country where you are located before using this eBook Title Pride and Prejudice Author Jane Austen Release date June 1 1998 Most recently updated April 14 2023 Language English Credits Chuck Greif and the Online Distributed Proofreading Team at http//www pgdp net START OF THE PROJECT GUTENBERG EBOOK PRIDE AND PREJUDICE Illustration GEORGE ALLEN PUBLISHER 156 CHARING CROSS ROAD LONDON RUSKIN HOUSE Illustration _Reading Janes Letters _ _Chap 34 _ PRIDE and PREJUDICE by Jane Austen with a Preface by George Saintsbury and Illustrations by Hugh Thomson Ruskin 156 '

# %% [markdown]
# ### [Exercise 3a] Find the top X frequency words
#
# Modify the freq function above [you can call it freq_x(s,top):] to work on words instead of characters and also give it a new parameter that is an integer value called top which will return the highest frequency words. Notice how the code in the return statement in freq give you all the words starting with the highest frequency? Well you can slice that to get the top values:

# %%
#if you have a dictionary of chars or words with frequencies as values...

topall = {k:D[k] for k in sorted(D,key=lambda x: D[x])[::-1]}      #gives a new dict with all values sorted by freq
top10  = {k:D[k] for k in sorted(D,key=lambda x: D[x])[::-1][:10]} #gives the top ten
top20  = {k:D[k] for k in sorted(D,key=lambda x: D[x])[::-1][:20]} #now it is the top 20
print(top20)
# Out:
# {'the': 661, 'I': 614, 'and': 542, 'of': 446, 'to': 410, 'my': 396, 'you': 396, 'a': 325, 'in': 267, 'not': 261, 'that': 242, 'me': 225, 'your': 202, 'is': 196, 'him': 195, 'have': 187, 'his': 182, 'this': 181, 'with': 168, 'thou': 164}

# %%
#Exercise 3a code here

def freq_x(s,top):
    D = {}  # Creating an empty dictionary to add words to

    for x in s.split(" "): # Looping through every word and creating a dictionary
        if x in D: D[x] += 1
        else:      D[x]  = 1
        
    return {k:D[k] for k in sorted(D,key=lambda x: D[x])[::-1][:top]} # Sorting the words and returning top ones.

freq_x(pride,10) # Top 10 words in pride
# Out:
# {'the': 4511,
#  'to': 4309,
#  'of': 3927,
#  'and': 3625,
#  'her': 2168,
#  'a': 2021,
#  'in': 1943,
#  'was': 1869,
#  'I': 1855,
#  'that': 1555}

# %% [markdown]
# ### [Exercise 3b] Now subtract the top words
#
# If you function is working, you can now test it out by removing those words from a given text. Some ideas are outlined below.

# %%
D = freq(pride)
D.pop(' ') #leave the spaces...
top5 = {k:D[k] for k in sorted(D,key=lambda x: D[x])[::-1][:5]}
top5 #get the top10 high frequency letters

for k in top5:
    pride = pride.replace(k,'') #remove the high frequency
pride[:1000]
# Out:
# 'Th Prjc Gubrg Bk f Prid d Prjudic This bk is fr h us f y ywhr i h Uid Ss d ms hr prs f h wrld   cs d wih lms  rsricis whsvr Yu my cpy i giv i wy r r-us i udr h rms f h Prjc Gubrg Lics icludd wih his bk r li  www gubrg rg If yu r  lcd i h Uid Ss yu will hv  chck h lws f h cury whr yu r lcd bfr usig his Bk Til Prid d Prjudic Auhr J Aus Rls d Ju 1 1998 Ms rcly updd April 14 2023 Lgug Eglish Crdis Chuck Grif d h Oli Disribud Prfrdig Tm  hp//www pgdp  START OF THE PROJECT GUTENBERG EBOOK PRIDE AND PREJUDICE Illusri GEORGE ALLEN PUBLISHER 156 CHARING CROSS ROAD LONDON RUSKIN HOUSE Illusri _Rdig Js Lrs _ _Chp 34 _ PRIDE d PREJUDICE by J Aus wih  Prfc by Grg Sisbury d Illusris by Hugh Thms Ruski 156 Chrig Hus Crss Rd Ld Grg All CHISWICK PRESSCHARLES WHITTINGHAM AND CO TOOKS COURT CHANCERY LANE LONDON Illusri _T J Cmys Crr i ckwldgm f ll I w  his fridship d dvic hs illusris r grfully iscribd_ _Hugh Thms_ _Wl Whim hs smwhr  fi d jus disici bw lvig by llwc d lvig wih prsl lv  This disici pplis  b'

# %%
# [Exercise 3b] code here
pride = read_and_process_text('pride_and_prejudice.txt') # Reading pride again because we removed letters

print(len(pride))       # Printing the length of pride to see the first length before removal
D = freq_x(pride, 20)   # Top 20 words in pride
print(D)                # Printing top 20 words before removal

for w in D: # Looping through every word
    pride = pride.replace(" " + w + " ", ' ') # Replacing every word by space.
    # I added " " around the word because I want to replace words. 'he' part of The shouldn't be replaced.

print(len(pride))       # Printing the length after replacement to see if I was successfull or not. 
D = freq_x(pride, 20)   # Top 20 words in pride (removed version)
print(D)                # Printing the top 20 words again and we can see that they changed.
# Out:
# 709085
# {'the': 4511, 'to': 4309, 'of': 3927, 'and': 3625, 'her': 2168, 'a': 2021, 'in': 1943, 'was': 1869, 'I': 1855, 'that': 1555, 'not': 1482, 'she': 1401, 'it': 1333, '': 1330, 'be': 1271, 'his': 1205, 'you': 1190, 'as': 1179, 'had': 1153, 'he': 1109}
# 572668
# {'with': 1107, 'for': 1084, 'is': 918, 'have': 872, 'Mr': 804, 'at': 781, 'him': 760, 'on': 703, 'but': 703, 'by': 671, 'all': 643, 'Elizabeth': 604, 'so': 595, 'my': 591, 'which': 567, 'were': 563, 'been': 535, 'could': 521, 'from': 501, 'very': 487}

# %% [markdown]
# #### [Extra Credit 10pts] Intersection of high frequency words
#
# Ideally you want to subtract a common set of high frequency words. To do this you need to apply the freq_x function on every text. Take the top 100-500 words from each and then use set intersection to build your stoplist (negative dictionary of common high frequency words)

# %%
# [Extra Credit]

# Reading every text and storing top 500 words.
tale = freq_x(read_and_process_text('a_tale_of_two_cities.txt'),500)
dracula = freq_x(read_and_process_text('dracula.txt'),500)
hamlet = freq_x(read_and_process_text('hamlet_shakespeare.txt'),500)
lear = freq_x(read_and_process_text('king_lear_shakespeare.txt'),500)
macbeth= freq_x(read_and_process_text('macbeth_shakespeare.txt'),500)
pride = freq_x(read_and_process_text('pride_and_prejudice.txt'),500)
karamazov= freq_x(read_and_process_text('the_brothers_karamazov.txt'),500)
illiad = freq_x(read_and_process_text('the_illiad.txt'),500)
merchant = freq_x(read_and_process_text('the_merchant_of_venice_shakespeare.txt'),500)

# Intersection of the every top word file
inter = set(tale).intersection(
    set(dracula).intersection(
    set(hamlet).intersection(
    set(lear).intersection(
    set(macbeth).intersection(
    set(pride).intersection(
    set(karamazov).intersection(
    set(illiad).intersection(
    set(merchant).intersection(
    )))))))))
inter   # This is a list of the common high frequency words in all of the text files.
        # I can use this in any text file to replace common high freq. words.
# Out:
# {'A',
#  'And',
#  'As',
#  'But',
#  'He',
#  'His',
#  'How',
#  'I',
#  'If',
#  'In',
#  'It',
#  'My',
#  'No',
#  'That',
#  'The',
#  'There',
#  'They',
#  'This',
#  'To',
#  'What',
#  'When',
#  'a',
#  'again',
#  'all',
#  'an',
#  'and',
#  'any',
#  'are',
#  'as',
#  'at',
#  'away',
#  'be',
#  'been',
#  'before',
#  'both',
#  'but',
#  'by',
#  'can',
#  'could',
#  'down',
#  'even',
#  'ever',
#  'eyes',
#  'first',
#  'for',
#  'from',
#  'give',
#  'great',
#  'had',
#  'have',
#  'he',
#  'head',
#  'hear',
#  'heard',
#  'heart',
#  'her',
#  'here',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'if',
#  'in',
#  'into',
#  'is',
#  'it',
#  'know',
#  'last',
#  'let',
#  'life',
#  'like',
#  'love',
#  'made',
#  'make',
#  'man',
#  'many',
#  'may',
#  'me',
#  'men',
#  'mind',
#  'more',
#  'most',
#  'much',
#  'must',
#  'my',
#  'night',
#  'no',
#  'not',
#  'now',
#  'of',
#  'on',
#  'once',
#  'one',
#  'or',
#  'other',
#  'our',
#  'out',
#  'own',
#  'place',
#  'see',
#  'shall',
#  'she',
#  'should',
#  'so',
#  'some',
#  'still',
#  'such',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'thought',
#  'time',
#  'to',
#  'too',
#  'two',
#  'up',
#  'upon',
#  'us',
#  'was',
#  'way',
#  'we',
#  'well',
#  'were',
#  'what',
#  'when',
#  'where',
#  'which',
#  'who',
#  'will',
#  'with',
#  'word',
#  'would',
#  'yet',
#  'you',
#  'your'}

# %% [markdown]
# #### [Part 4] Visualizing your efforts
# This is the fun part, where you get to visualize the results of your processing in part [1],[2],[3] will make those items more understandable.  A common visualization method is called a word cloud. You will make a few of these to see the effects of our processing on the final cloud. There is a library to install either using the pip or conda command.

# %%
# %pip install wordcloud
#%conda install wordcloud #alterate way to install
# Out:
# Requirement already satisfied: wordcloud in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wordcloud) (10.0.1)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/deringezgin/Library/Python/3.11/lib/python/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/deringezgin/Library/Python/3.11/lib/python/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/deringezgin/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### [Exercise 4a] Regular Word cloud
#
# For this one you should load the text for one of the plays, you don't have to chop it up, you can just call the read_and_process_text method which gives you all the text.

# %%
# [Exercise 4a] code here
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = read_and_process_text('hamlet_shakespeare.txt') # Reading hamlet with the method

# Generating a regular word cloud
wc = WordCloud().generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# #### [Exercise 4b] word cloud with common words removed
# Now use your common words (stop words) that you calculated in part 3. Play around with removing top 10,50,100, etc common words. You should see some of the smaller words in the picture become the larger ones if you remove enough of the common words. You can keep removing until the visualization shows words that are connected to the text.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = read_and_process_text('king_lear_shakespeare.txt') #text is just a string

# Example of how to use the wordcloud visualization tool!!
wc = WordCloud().generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# [Exercise 4b] code here
for i in [10,50,100]:
    hamlet = read_and_process_text('hamlet_shakespeare.txt') # Reading the text

    D = freq_x(hamlet, i) # Taking top i words

    for w in D: # Replacing top i words in the text
        hamlet = hamlet.replace(" " + w + " ", ' ')

    # Creating the image
    wc = WordCloud().generate(hamlet)
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### [5 20pts] Share your thoughts on the LAB.
# Was this one more difficult than the last one? What was the most interesting thing you learned here in this material? Do you want to see a particuliar type or form of data in a future LAB?

# %% [markdown]
# I think that this lab was more difficult than the previous labs. But I also had fun while completing the lab. I'd like to see more Labs like this. The hardest part of this Lab is I've never worked with a similar data so I had to get outside my comfort zone (of knowledge) in order to complete this lab.
#
# As I said, it was fun but also hard.
